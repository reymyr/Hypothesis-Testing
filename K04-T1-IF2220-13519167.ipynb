# %% [markdown]
# # Tugas Besar IF2220 Probabilitas dan Statistika
#
# ### Nama Anggota Kelompok:
# 1. Reyhan Emyr Arrosyid         - 13519167
# 2. Muhammad Dehan Al Kautsar    - 13519200

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats
import math

# Set taraf signifikansi
alpha = 0.05

# Baca file Gandum.csv
columnNames = ["id", "Daerah", "SumbuUtama", "SumbuKecil", "Keunikan", "AreaBulatan", "Diameter", "KadarAir", "Keliling", "Bulatan", "Ransum", "Kelas"]
df = pd.read_csv("Gandum.csv", names=columnNames)
df
# Out:
#       id  Daerah  SumbuUtama  SumbuKecil  Keunikan  AreaBulatan   Diameter  \
# 0      1    5781  128.288875   58.470846  0.890095         5954  85.793926
# 1      2    4176  109.348294   49.837688  0.890098         4277  72.918093
# 2      3    4555  114.427991   52.151207  0.890105         4706  76.155145
# 3      4    4141  108.701190   49.457349  0.890499         4236  72.611879
# 4      5    5273  122.747868   55.757848  0.890876         5431  81.937733
# ..   ...     ...         ...         ...       ...          ...        ...
# 495  496    5083  120.083450   54.821580  0.889709         5179  80.447975
# 496  497    4432  112.367050   51.294914  0.889726         4550  75.119889
# 497  498    5020  119.873742   54.718545  0.889740         5104  79.947874
# 498  499    4035  107.311728   48.930802  0.889996         4150  71.676506
# 499  500    3379   99.014789   44.631551  0.892647         3491  65.591741
#
#      KadarAir  Keliling   Bulatan    Ransum  Kelas
# ...

# %% [markdown]
# # 1. Menulis deskripsi statistika (Descriptive Statistics) dari semua kolom pada data yang bersifat numerik, terdiri dari mean, median, modus, standar deviasi, variansi, range, nilai minimum, maksimum, kuartil, IQR, skewness dan kurtosis. Boleh juga ditambahkan deskripsi lain.
#
# Untuk mendapatkan nilai deskripsi statistika dengan python digunakan beberapa fungsi, misal df adalah sebuah variabel dataFrame, maka
# - Mean didapatkan dengan fungsi df.mean()
# - Median didapatkan dengan fungsi df.median()
# - Modus didapatkan dengan fungsi df.mode()
# - Standar deviasi didapatkan dengan fungsi df.std()
# - Variansi didapatkan dengan fungsi df.var()
# - Range didapatkan dengan mengurangi nilai minimum pada nilai maksimum dengan fungsi df.max()-df.min()
# - Nilai minimum didapatkan dengan fungsi df.min()
# - Nilai maksimum didapatkan dengan fungsi df.max()
# - Kuartil didapatkan dengan fungsi df.quantile(x) dengan x menandakan quantile ke-berapa (Contoh x=0.25 untuk kuartil 1)
# - IQR didapatkan dengan mengurangi kuartil 1 pada kuartil 3 dengan fungsi df.quantile(0.75)-df.quantile(0.25)
# - Skewness didapatkan dengan fungsi df.skew()
# - Kurtosis didapatkan dengan fungsi df.kurt(), yaitu definisi kurtosis Fisher

# %%
def getStatisticDescription(df):
    print("Mean \t\t=", df.mean())
    print("Median \t\t=", df.median())
    modus = df.mode()
    print("Modus \t\t= ", end="")
    for i in range(len(modus)):
        if i != 0:
            print(", ", end="")
        print(modus[i], end="")
    print()
    print("Standar Deviasi =", df.std())
    print("Variansi \t=", df.var())
    print("Range \t\t=", df.max()-df.min())
    print("Nilai Minimum \t=", df.min())
    print("Nilai Maksimum \t=", df.max())
    print("Q1 \t\t=", df.quantile(0.25))
    print("Q2 \t\t=", df.quantile(0.5))
    print("Q3 \t\t=", df.quantile(0.75))
    print("IQR \t\t=", df.quantile(0.75)-df.quantile(0.25))
    print("Skewness \t=", df.skew())
    print("Kurtosis \t=", df.kurt())

# %% [markdown]
# ## Kolom Id
# Id hanya sebuah pembeda setiap row, sehingga deskripsi statistik dari kolom Id tidak diperlukan

# %% [markdown]
# ## Kolom Daerah

# %%
getStatisticDescription(df["Daerah"])
# Out:
# Mean 		= 4801.246
# Median 		= 4735.0
# Modus 		= 3992, 4881, 5642, 6083
# Standar Deviasi = 986.3954914816017
# Variansi 	= 972976.0656152305
# Range 		= 4931
# Nilai Minimum 	= 2522
# Nilai Maksimum 	= 7453
# Q1 		= 4042.75
# Q2 		= 4735.0
# Q3 		= 5495.5
# IQR 		= 1452.75
# Skewness 	= 0.23814408738280812
# Kurtosis 	= -0.4346305340273977

# %% [markdown]
# ## Kolom SumbuUtama

# %%
getStatisticDescription(df["SumbuUtama"])
# Out:
# Mean 		= 116.04517136778
# Median 		= 115.40513995
# ...

# %% [markdown]
# ## Kolom SumbuKecil

# %%
getStatisticDescription(df["SumbuKecil"])
# Out:
# Mean 		= 53.71524598896
# Median 		= 53.731198774999996
# ...

# %% [markdown]
# ## Kolom Keunikan

# %%
getStatisticDescription(df["Keunikan"])
# Out:
# Mean 		= 0.8787639143399999
# Median 		= 0.8900454185
# ...

# %% [markdown]
# ## Kolom AreaBulatan

# %%
getStatisticDescription(df["AreaBulatan"])
# Out:
# Mean 		= 4937.048
# Median 		= 4857.0
# Modus 		= 3802, 4913
# Standar Deviasi = 1011.6962549701573
# Variansi 	= 1023529.3123206414
# Range 		= 5141
# Nilai Minimum 	= 2579
# Nilai Maksimum 	= 7720
# Q1 		= 4170.25
# Q2 		= 4857.0
# Q3 		= 5654.25
# IQR 		= 1484.0
# Skewness 	= 0.2575600053152032
# Kurtosis 	= -0.40968492037366033

# %% [markdown]
# ## Kolom Diameter

# %%
getStatisticDescription(df["Diameter"])
# Out:
# Mean 		= 77.77115780832001
# Median 		= 77.64527658
# Modus 		= 71.29356396, 78.83325579, 84.75622403, 88.00634154
# Standar Deviasi = 8.056867291849713
# Variansi 	= 64.91311055847774
# Range 		= 40.747172240000005
# Nilai Minimum 	= 56.66665803
# Nilai Maksimum 	= 97.41383027
# Q1 		= 71.7453075475
# Q2 		= 77.64527658
# Q3 		= 83.6485975675
# IQR 		= 11.90329002
# Skewness 	= 0.002724966865193717
# Kurtosis 	= -0.46645451303121455

# %% [markdown]
# ## Kolom KadarAir

# %%
getStatisticDescription(df["KadarAir"])
# Out:
# Mean 		= 0.6483716718979999
# Median 		= 0.626116699
# Modus 		= 0.735849057, 0.824404762
# Standar Deviasi = 0.09436709809379533
# Variansi 	= 0.00890514920264399
# Range 		= 0.46897193099999995
# Nilai Minimum 	= 0.409927152
# Nilai Maksimum 	= 0.878899083
# Q1 		= 0.57263245725
# Q2 		= 0.626116699
# Q3 		= 0.7266333445
# IQR 		= 0.15400088724999994
# Skewness 	= 0.49366131797330265
# Kurtosis 	= -0.7403261705867821

# %% [markdown]
# ## Kolom Keliling

# %%
getStatisticDescription(df["Keliling"])
# Out:
# Mean 		= 281.4797219999999
# Median 		= 280.0455
# ...

# %% [markdown]
# ## Kolom Bulatan

# %%
getStatisticDescription(df["Bulatan"])
# Out:
# Mean 		= 0.7617374363080001
# Median 		= 0.7612884394999999
# ...

# %% [markdown]
# ## Kolom Ransum

# %%
getStatisticDescription(df["Ransum"])
# Out:
# Mean 		= 2.150915331084
# Median 		= 2.1935990365
# ...

# %% [markdown]
# ## Kolom Kelas
# Kolom kelas merupakan klasifikasi dari sebuah gandum sehingga deskripsi statistik tidak perlu dicari

# %% [markdown]
# # 2. Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plottersebut.

# %%
def drawHistAndBoxplot(df):
    f, axes = plt.subplots(1, 2, figsize=(16, 6))
    sns.histplot(data=df, ax=axes[0])
    
    sns.boxplot(data=df, orient="x", ax=axes[1], width=0.15)

# %% [markdown]
# ## Kolom Daerah

# %%
drawHistAndBoxplot(df["Daerah"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat data tidak condong pada satu sisi. Karena itu, dapat disimpulkan skewness data kolom Daerah bersifat symmetrical distribution. Dari histogram juga dapat dilihat data cukup tersebar sehingga dihasilkan histogram yang tidak terlalu lancip dan tidak terlalu landai. Hal ini menandakan data dalam kolom Daerah bersifat mesokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 4000, median data bernilai sekitar 4700, dan kuartil 3 data bernilai sekitar 5500. Dari boxplot juga dapat dilihat bahwa data dalam kolom Daerah tidak memiliki pencilan.

# %% [markdown]
# ## Kolom SumbuUtama

# %%
drawHistAndBoxplot(df["SumbuUtama"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat ada data yang bernilai di sekitar 220 dan data mayoritas berada di sisi kiri. Oleh karena itu, skewness data kolom SumbuUtama bersifat positive skew. Dari histogram juga dapat dilihat data tidak terlalu tersebar dan dihasilkan histogram yang lancip. Hal ini menandakan data dalam kolom SumbuUtama bersifat leptokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 105, median data bernilai sekitar 115, dan kuartil 3 data bernilai sekitar 130. Dari boxplot juga dapat dilihat bahwa terdapat pencilan dalam data kolom SumbuUtama dengan nilai sekitar 220. Pencilan ini bernilai jauh lebih besar dari data lainnya.

# %% [markdown]
# ## Kolom SumbuKecil

# %%
drawHistAndBoxplot(df["SumbuKecil"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat data tidak condong pada satu sisi. Karena itu, dapat disimpulkan skewness data kolom SumbuKecil bersifat symmetrical distribution. Dari histogram juga dapat dilihat data cukup tersebar sehingga dihasilkan histogram yang tidak terlalu lancip dan tidak terlalu landai. Hal ini menandakan data dalam kolom SumbuKecil bersifat mesokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 51, median data bernilai sekitar 53, dan kuartil 3 data bernilai sekitar 56. Dari boxplot juga dapat dilihat bahwa terdapat beberapa pencilan dalam data kolom SumbuKecil dengan nilai. Terdapat 4 pencilan bawah dan 2 pencilan atas.

# %% [markdown]
# ## Kolom Keunikan

# %%
drawHistAndBoxplot(df["Keunikan"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat bahwa mayoritas data berada di sisi kanan. Oleh karena itu, skewness data kolom Keunikan bersifat negative skew. Dari histogram juga dapat dilihat terdapat data dengan frekuensi yang besar yaitu data yang bernilai lebih dari 0,9. Hal ini menyebabkan histogram yang lancip sehingga data kolom Keunikan bersifat leptokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 0,86, median data bernilai sekitar 0,89, dan kuartil 3 data bernilai sekitar 0,91. Dari boxplot juga dapat dilihat bahwa terdapat banyak pencilan dalam data kolom Keunikan. Semua nilai pencilan ini merupakan pencilan bawah.

# %% [markdown]
# ## Kolom AreaBulatan

# %%
drawHistAndBoxplot(df["AreaBulatan"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat data tidak condong pada satu sisi. Karena itu, dapat disimpulkan skewness data kolom AreaBulatan bersifat symmetrical distribution. Dari histogram juga dapat dilihat data cukup tersebar sehingga dihasilkan histogram yang tidak terlalu lancip dan tidak terlalu landai. Hal ini menandakan data dalam kolom AreaBulatan bersifat mesokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 4100, median data bernilai sekitar 4800, dan kuartil 3 data bernilai sekitar 5600. Dari boxplot juga dapat dilihat bahwa data dalam kolom AreaBulatan tidak memiliki pencilan.

# %% [markdown]
# ## Kolom Diameter

# %%
drawHistAndBoxplot(df["Diameter"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat data tidak condong pada satu sisi. Karena itu, dapat disimpulkan skewness data kolom Diameter bersifat symmetrical distribution. Dari histogram juga dapat dilihat data cukup tersebar sehingga dihasilkan histogram yang tidak terlalu lancip dan tidak terlalu landai. Hal ini menandakan data dalam kolom Diameter bersifat mesokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 72, median data bernilai sekitar 78, dan kuartil 3 data bernilai sekitar 84. Dari boxplot juga dapat dilihat bahwa data dalam kolom Diameter tidak memiliki pencilan.

# %% [markdown]
# ## Kolom KadarAir

# %%
drawHistAndBoxplot(df["KadarAir"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat data tidak condong pada satu sisi. Karena itu, dapat disimpulkan skewness data kolom KadarAir bersifat skew positive. Dari histogram juga dapat dilihat data cukup tersebar sehingga dihasilkan histogram yang tidak terlalu lancip dan tidak terlalu landai. Hal ini menandakan data dalam kolom KadarAir bersifat mesokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 0.57, median data bernilai sekitar 0.62, dan kuartil 3 data bernilai sekitar 0.72. Dari boxplot juga dapat dilihat bahwa data dalam kolom KadarAir tidak memiliki pencilan.

# %% [markdown]
# ## Kolom Keliling

# %%
drawHistAndBoxplot(df["Keliling"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat bahwa mayoritas data berada di sisi kiri. Oleh karena itu, skewness data kolom Keliling bersifat positive skew. Dari histogram juga dapat dilihat terdapat data dengan frekuensi yang besar yaitu data yang bernilai kurang dari 260. Hal ini menyebabkan histogram yang lancip sehingga data kolom Keliling bersifat leptokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 256, median data bernilai sekitar 280, dan kuartil 3 data bernilai sekitar 306. Dari boxplot juga dapat dilihat bahwa terdapat banyak pencilan dalam data kolom Keliling. Semua nilai pencilan ini merupakan pencilan atas.

# %% [markdown]
# ## Kolom Bulatan

# %%
drawHistAndBoxplot(df["Bulatan"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat bahwa mayoritas data berada di sisi kanan. Oleh karena itu, skewness data kolom Bulatan bersifat negative skew. Dari histogram juga dapat dilihat terdapat data dengan frekuensi yang besar yaitu data yang bernilai kurang dari 260. Hal ini menyebabkan histogram yang lancip sehingga data kolom Bulatan bersifat leptokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 0.73, median data bernilai sekitar 0.76, dan kuartil 3 data bernilai sekitar 0.8. Dari boxplot juga dapat dilihat bahwa terdapat banyak pencilan dalam data kolom Keliling. Hampir semua nilai pencilan ini merupakan pencilan bawah dan beberapa dari pencilan atas.

# %% [markdown]
# ## Kolom Ransum

# %%
drawHistAndBoxplot(df["Ransum"])

# %% [markdown]
# ### Penjelasan
# Dari histogram yang dihasilkan, dapat dilihat bahwa mayoritas data berada di sisi kanan. Oleh karena itu, skewness data kolom Ransum bersifat negative skew. Dari histogram juga dapat dilihat bahwa data tersebar merata. Hal ini menyebabkan histogram yang tidak lancip dan tidak landai sehingga data kolom Ransum bersifat mesokurtic.
#
# Dari boxplot yang dihasilkan, dapat dilihat kuartil 1 data bernilai sekitar 2, median data bernilai sekitar 2.2, dan kuartil 3 data bernilai sekitar 2.4. Dari boxplot juga dapat dilihat bahwa tidak terdapat pencilan dalam data kolom Ransum.

# %% [markdown]
# # 3. Menentukan setiap kolom numerik berdistribusi normal atau tidak. Gunakan normality test yang dikaitkan dengan histogram plot
# Normality test digunakan dengan memanfaatkan library SciPy dengan fungsi stats.normaltest(). Fungsi ini akan menghitung p-value dengan H0 adalah data berdistribusi normal. P-value tersebut lalu dibandingkan dengan taraf signifikansi yang sudah ditentukan dalam hal ini 0.05. Jika nilai p-value yang didapat lebih kecil dari alpha, H0 ditolak atau data tidak berdistribusi normal. Jika tidak, H0 diterima yang berarti data berdistribusi normal. Setelah itu histogram data digambar dan dibandingkan dengan grafik distribusi normal yang memiliki nilai minimal, nilai maksimal, mean, dan standar deviasi yang sama dengan data.

# %%
def normalTest(df, alpha):
    k2, p = stats.normaltest(df)
    print("p = {:g}".format(p))
    if p < alpha:  # H0 berarti data berdistribusi normal
        print("H0 ditolak, data tidak berdistribusi normal")
    else:
        print("H0 diterima, data berdistribusi normal")
    
    # Gambar perbandingan histogram dengan kurva distribusi normal
    mu, std = stats.norm.fit(df)
    plt.hist(df, density=True)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    y = stats.norm.pdf(x, mu, std)
    plt.plot(x, y, 'r', lw="3")
    plt.show()

# %% [markdown]
# ## Kolom Daerah

# %%
normalTest(df["Daerah"], alpha)
# Out:
# p = 0.00438627
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom Daerah bersifat symmetrical distribution sehingga seseorang dapat berasumsi data berdistribusi normal, tetapi berdasarkan normamility test, data kolom Daerah tidak berdistribusi normal. Hal ini dapat disebabkan nilai mean, median, dan modus data yang tidak memenuhi kriteria distribusi normal.

# %% [markdown]
# ## Kolom SumbuUtama

# %%
normalTest(df["SumbuUtama"], alpha)
# Out:
# p = 2.21274e-21
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom SumbuUtama bersifat positive skew sehingga data tidak berdistribusi normal. Hal ini diperkuat dengan hasil normamility test yang menghasilkan data kolom SumbuUtama tidak berdistribusi normal.

# %% [markdown]
# ## Kolom SumbuKecil

# %%
normalTest(df["SumbuKecil"], alpha)
# Out:
# p = 0.157363
# H0 diterima, data berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom SumbuKecil bersifat symmetrical distribution sehingga seseorang dapat berasumsi data berdistribusi normal. Kepastian dari suatu data berdistribusi normal atau tidak dapat dipastikan dengan normality test dan berdasarkan normamility test, data kolom SumbuKecil berdistribusi normal.

# %% [markdown]
# ## Kolom Keunikan

# %%
normalTest(df["Keunikan"], alpha)
# Out:
# p = 3.60297e-35
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom Keunikan bersifat negative skew sehingga data tidak berdistribusi normal. Hal ini diperkuat dengan hasil normamility test yang menghasilkan data kolom Keunikan tidak berdistribusi normal.

# %% [markdown]
# ## Kolom AreaBulatan

# %%
normalTest(df["AreaBulatan"], alpha)
# Out:
# p = 0.00465706
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom AreaBulatan bersifat symmetrical distribution sehingga seseorang dapat berasumsi data berdistribusi normal, tetapi berdasarkan normamility test, data kolom AreaBulatan tidak berdistribusi normal. Hal ini dapat disebabkan nilai mean, median, dan modus data yang tidak memenuhi kriteria distribusi normal.

# %% [markdown]
# ## Kolom Diameter

# %%
normalTest(df["Diameter"],alpha)
# Out:
# p = 0.0241572
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom Diameter bersifat symmetrical distribution sehingga seseorang dapat berasumsi data berdistribusi normal, tetapi berdasarkan normamility test, data kolom Diameter tidak berdistribusi normal. Hal ini dapat disebabkan nilai mean, median, dan modus data yang tidak memenuhi kriteria distribusi normal.

# %% [markdown]
# ## Kolom KadarAir

# %%
normalTest(df["KadarAir"],alpha)
# Out:
# p = 2.58694e-11
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom KadarAir bersifat positive skew sehingga data tidak berdistribusi normal. Hal ini diperkuat dengan hasil normamility test yang menghasilkan data kolom KadarAir tidak berdistribusi normal.

# %% [markdown]
# ## Kolom Keliling

# %%
normalTest(df["Keliling"],alpha)
# Out:
# p = 2.23901e-15
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom Keliling bersifat positive skew sehingga data tidak berdistribusi normal. Hal ini diperkuat dengan hasil normamility test yang menghasilkan data kolom Keliling tidak berdistribusi normal.

# %% [markdown]
# ## Kolom Bulatan

# %%
normalTest(df["Bulatan"],alpha)
# Out:
# p = 9.88528e-97
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom Bulatan bersifat negative skew sehingga data tidak berdistribusi normal. Hal ini diperkuat dengan hasil normamility test yang menghasilkan data kolom Bulatan tidak berdistribusi normal.

# %% [markdown]
# ## Kolom Ransum

# %%
normalTest(df["Ransum"],alpha)
# Out:
# p = 8.96301e-09
# H0 ditolak, data tidak berdistribusi normal

# %% [markdown]
# Menurut hasil histogram, data kolom Ransum bersifat negative skew sehingga data tidak berdistribusi normal. Hal ini diperkuat dengan hasil normamility test yang menghasilkan data kolom Ransum tidak berdistribusi normal.

# %% [markdown]
# # 4. Melakukan test hipotesis 1 sampel, dengan menuliskan 6 langkah testing dan menampilkan juga boxplotnya untuk kolom/bagian yang bersesuaian.

# %% [markdown]
# ### 6 langkah testing:
# 1. Tentukan Hipotesis nol (H0 : θ = θ0), dimana θ bisa berupa μ, σ^2, p, atau data lain berdistribusi tertentu (normal, binomial, dsc.).
#
# 2. Pilih hipotesis alternatif H1 salah dari dari θ > θ0, θ < θ0, atau θ ≠ θ0.
#
# 3. Tentukan tingkat signifikan α.
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
# 5. Hitung nilai uji statistik dari data sample. Hitung p-value sesuai dengan uji statistik yang digunakan.
#
# 6. Ambil keputusan dengan TOLAK H0 jika nilai uji terletak di daerah kritis atau dengan tes signifikan, TOLAK H0 jika p-value lebih kecil dibanding tingkat signifikansi α yang diinginkan

# %%
def meanTestZ(xbar, miu0, sigma, n):
    return (xbar - miu0)*math.sqrt(n)/sigma

def proportionTestZ(p, p0, n):
    return (p-p0)/math.sqrt(p0*(1-p0)/n)

# %% [markdown]
# ## 4a. Nilai rata-rata Daerah di atas 4700
# - Ditentukan hipotesis nol H0 : μ = 4700
# - Kemudian dipilih hipotesis alternatif H1 : μ > 4700
# - Selanjutnya ditentukan tingkat signifikan α = 0.05
# - Akan digunakan uji statistik tes mean menggunakan Z, dan daerah kritis : z > 1.645 diketahui dari P(Z < z) = 0.95
# - Akan dihitung nilai uji statistik atau p-valuenya

# %%
z = meanTestZ(df["Daerah"].mean(),4700,df["Daerah"].std(),df["Daerah"].count())
print("Nilai uji =", z)
pValue = (1 - stats.norm.cdf(z))
print("P-value =", pValue)

if z > 1.645:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")
if pValue < alpha:
    print("H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha")
else:
    print("H0 diterima dikarenakan nilai p-value lebih besar sama dengan alpha")

sns.boxplot(data=df["Daerah"], orient="x", width=0.15)
# Out:
# Nilai uji = 2.2951538242525173
# P-value = 0.010862155196799894
# H0 ditolak karena nilai uji terletak di daerah kritis
# H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha
# <AxesSubplot:>

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimmpulan yang dapat ditarik adalah rata-rata daerah diatas 4700. Hal ini diperkuat dengan nilai p-value yang lebih kecil daripada nilai alpha

# %% [markdown]
# ## 4b. Nilai rata-rata Sumbu Utama tidak sama dengan 116
# - Ditentukan hipotesis nol H0 : μ = 116
# - Kemudian dipilih hipotesis alternatif H1 : μ ≠ 116
# - Selanjutnya ditentukan tingkat signifikan α = 0.05
# - Akan digunakan uji statistik tes mean menggunakan Z, dan daerah kritis : z < -1.96 dan z > 1.96 diketahui dari P(Z < z) = +-0.975
# - Akan dihitung nilai uji statistik atau p-valuenya

# %%
z = meanTestZ(df["SumbuUtama"].mean(),116,df["SumbuUtama"].std(),df["SumbuUtama"].count())
print("Nilai uji =", z)
pValue = 2*(1 - stats.norm.cdf(z))
print("P-value =", pValue)

if z < -1.96 or z > 1.96:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")
if pValue < alpha:
    print("H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha")
else:
    print("H0 diterima dikarenakan nilai p-value lebih besar sama dengan alpha")

sns.boxplot(data=df["SumbuUtama"], orient="x", width=0.15)
# Out:
# Nilai uji = 0.05524712326730106
# P-value = 0.9559415872977521
# H0 diterima karena nilai uji terletak di luar daerah kritis
# H0 diterima dikarenakan nilai p-value lebih besar sama dengan alpha
# <AxesSubplot:>

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol diterima, maka kesimpulan yang dapat ditarik adalah rata-rata Sumbu Utama adalah 116. Hal ini dibuktikan dengan nilai p-value yang lebih besar daripada nilai alpha

# %% [markdown]
# ## 4c. Nilai Rata-rata 20 baris pertama kolom Sumbu Kecil bukan 50
# - Ditentukan hipotesis nol H0 : μ = 50
# - Kemudian dipilih hipotesis alternatif H1 : μ ≠ 50
# - Selanjutnya ditentukan tingkat signifikan α = 0.05
# - Akan digunakan uji statistik tes mean menggunakan Z, dan daerah kritis : z < -1.96 dan z > 1.96 diketahui dari P(Z < z) = 0.975
# - Akan dihitung nilai uji statistik atau p-valuenya

# %%
z = meanTestZ(df["SumbuKecil"].head(20).mean(),50,df["SumbuKecil"].std(),df["SumbuKecil"].head(20).count())
print("Nilai uji =", z)
pValue = 2*(1 - stats.norm.cdf(z))
print("P-value =", pValue)

if z < -1.96 or z > 1.96:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")
if pValue < alpha:
    print("H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha")
else:
    print("H1 diterima dikarenakan nilai p-value lebih besar sama dengan alpha")

sns.boxplot(data=df["SumbuKecil"].head(20), orient="x", width=0.15)
# Out:
# Nilai uji = 5.368745408889905
# P-value = 7.928624956576868e-08
# H0 ditolak karena nilai uji terletak di daerah kritis
# H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha
# <AxesSubplot:>

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimpulan yang dapat ditarik adalah rata-rata 20 baris pertama Sumbu Kecil tidak sama dengan 50. Hal itu diperkuat dengan nilai p-value yang lebih kecil daripada nilai alpha

# %% [markdown]
# ## 4d. Proporsi nilai Diameter yang lebih dari 85, adalah tidak sama dengan 15%
# - Ditentukan hipotesis nol H0 : p0 = 0.15
# - Kemudian dipilih hipotesis alternatif H1 : p ≠ 0.15
# - Selanjutnya ditentukan tingkat signifikan α = 0.05
# - Akan digunakan uji statistik tes proporsi menggunakan Z, dan daerah kritis : z < -1.96 dan z > 1.96 diketahui dari P(Z < z) = 1 - (0.05/2) = 0.975
# - Akan dihitung nilai uji statistik atau p-valuenya

# %%
pAccent = 0
for i in range(len(df)):
    if df["Diameter"].iloc[i] > 85:
        pAccent += 1
pAccent = pAccent / len(df["Diameter"])

z = proportionTestZ(pAccent, 0.15, len(df["Diameter"]))
print("Nilai uji =", z)
pValue = 2*(1 - stats.norm.cdf(z))
print("P-value =", pValue)

if pValue < alpha:
    print("H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha")
else:
    print("H1 diterima dikarenakan nilai p-value lebih besar sama dengan alpha")

sns.boxplot(data=df["Diameter"], orient="x", width=0.15)
# Out:
# Nilai uji = 2.755386880774658
# P-value = 0.005862277168409591
# H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha
# <AxesSubplot:>

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimpulan yang dapat ditarik adalah proporsi data Diameter yang lebih dari 85 bukanlah sebesar 15%.

# %% [markdown]
# ## 4e. Proporsi nilai Keliling yang kurang dari 100, adalah kurang dari 5%
# - Ditentukan hipotesis nol H0 : p0 = 0.05
# - Kemudian dipilih hipotesis alternatif H1 : p < 0.05
# - Selanjutnya ditentukan tingkat signifikan α = 0.05
# - Akan digunakan uji statistik tes proporsi menggunakan Z, dan daerah kritis : z < -1.645 diketahui dari P(Z < z) = 0.95
# - Akan dihitung nilai uji statistik atau p-valuenya

# %%
pAccent = 0
for i in range(len(df)):
    if df["Keliling"].iloc[i] < 100:
        pAccent += 1
pAccent = pAccent / len(df["Keliling"])

z = proportionTestZ(pAccent, 0.05, len(df["Keliling"]))
pValue = stats.norm.cdf(z)
print("Nilai uji =", z)
print("P-value =", pValue)

if pValue < alpha:
    print("H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha")
else:
    print("H1 diterima dikarenakan nilai p-value lebih besar sama dengan alpha")

sns.boxplot(data=df["Keliling"], orient="x", width=0.15)
# Out:
# Nilai uji = -5.129891760425771
# P-value = 1.4495441414387716e-07
# H0 ditolak dikarenakan nilai p-value lebih kecil dibandingkan alpha
# <AxesSubplot:>

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimpulan yang dapat ditarik adalah proporsi data Keliling yang kurang dari 100 lebih kecil dari 5%. Dapat dilihat pula di soal nomor 1 bahwa nilai minimum keliling sebesar 197 sehingga tidak ada data Keliling yang mempunyai keliling yang kurang dari 100.

# %% [markdown]
# # 5. Melakukan test hipotesis 2 sampel, dengan menuliskan 6 langkah testing dan menampilkan juga boxplotnya untuk kolom/bagian yang bersesuaian.

# %% [markdown]
# ### 6 langkah testing:
# 1. Tentukan Hipotesis nol (H0 : θ = θ0), dimana θ bisa berupa μ, σ^2, p, atau data lain berdistribusi tertentu (normal, binomial, dsc.).
#
# 2. Pilih hipotesis alternatif H1 salah dari dari θ > θ0, θ < θ0, atau θ ≠ θ0.
#
# 3. Tentukan tingkat signifikan α.
#
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
#
# 5. Hitung nilai uji statistik dari data sample. Hitung p-value sesuai dengan uji statistik yang digunakan.
#
# 6. Ambil keputusan dengan TOLAK H0 jika nilai uji terletak di daerah kritis atau dengan tes signifikan, TOLAK H0 jika p-value lebih kecil dibanding tingkat signifikansi α yang diinginkan

# %%
def twoSampleMeanTestZ(df1, df2, d0, population):
    return ((df1.mean() - df2.mean()) - d0) / math.sqrt(population.var()/len(df1) + population.var()/len(df2))

# %% [markdown]
# ## 5a. Data kolom AreaBulatan dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata kedua bagian tersebut sama?
# Misal μ1 adalah rata-rata bagian awal dan μ2 adalah rata-rata bagian kedua. Langkah testing:
# 1. Ditentukan hipotesis nol H0 : μ1 - μ2 = 0
# 2. Kemudian dipilih hipotesis alternatif H1 : μ1 - μ2 ≠ 0
# 3. Selanjutnya ditentukan tingkat signifikan α = 0.05
# 4. Akan digunakan uji statistik tes mean menggunakan Z, dan daerah kritis : z < -1.96 atau z > 1.96 diketahui dari P(Z < z) = 1 - (0.05/2) = 0.975
# 5. Akan dihitung nilai uji statistik dan p-valuenya

# %%
z = twoSampleMeanTestZ(df["AreaBulatan"].head(250), df["AreaBulatan"].tail(250), 0, df["AreaBulatan"])
print("Nilai uji =", z)
pValue = 2 * min(stats.norm.cdf(z), 1-stats.norm.cdf(z))
print("P-value =", pValue)

# Langkah 6. Ambil keputusan
if z < -1.96 or z > 1.96:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")

sns.boxplot(data=[df["AreaBulatan"].head(250), df["AreaBulatan"].tail(250)], orient="x", width=0.15).set_title("Boxplot AreaBulatan1 dan AreaBulatan2")
# Out:
# Nilai uji = 13.543235559978203
# P-value = 0.0
# H0 ditolak karena nilai uji terletak di daerah kritis
# Text(0.5, 1.0, 'Boxplot AreaBulatan1 dan AreaBulatan2')

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimpulan yang dapat ditarik adalah rata-rata bagian awal dan bagian akhir kolom AreaBulatan berbeda.

# %% [markdown]
# ## 5b. Data kolom Kadar Air dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata bagian awal lebih besar dari pada bagian akhir sebesar 0.2?
# Misal μ1 adalah rata-rata bagian awal dan μ2 adalah rata-rata bagian kedua. Langkah testing:
# 1. Ditentukan hipotesis nol H0 : μ1 - μ2 = 0.2
# 2. Kemudian dipilih hipotesis alternatif H1 : μ1 - μ2 ≠ 0.2
# 3. Selanjutnya ditentukan tingkat signifikan α = 0.05
# 4. Akan digunakan uji statistik tes mean menggunakan Z, dan daerah kritis : z < -1.96 atau z > 1.96 diketahui dari P(Z < z) = 1 - (0.05/2) = 0.975
# 5. Akan dihitung nilai uji statistik dan p-valuenya

# %%
z = twoSampleMeanTestZ(df["KadarAir"].head(250), df["KadarAir"].tail(250), 0.2, df["KadarAir"])
print("Nilai uji =", z)
pValue = 2 * min(stats.norm.cdf(z), 1-stats.norm.cdf(z))
print("P-value =", pValue)

# Langkah 6. Ambil keputusan
if z < -1.96 or z > 1.96:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")

sns.boxplot(data=[df["KadarAir"].head(250), df["KadarAir"].tail(250)], orient="x", width=0.15).set_title("Boxplot KadarAir1 dan KadarAir2")
# Out:
# Nilai uji = -26.68773186701691
# P-value = 6.5335407786544e-157
# H0 ditolak karena nilai uji terletak di daerah kritis
# Text(0.5, 1.0, 'Boxplot KadarAir1 dan KadarAir2')

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimpulan yang dapat ditarik adalah rata-rata bagian awal tidak lebih besar dari pada bagian akhir sebesar 0.2.

# %% [markdown]
# ## 5c. Rata-rata 20 baris pertama kolom Bulatan sama dengan 20 baris terakhirnya?
# Misal μ1 adalah rata-rata 20 baris pertama dan μ2 adalah rata-rata 20 baris terakhir. Langkah testing:
# 1. Ditentukan hipotesis nol H0 : μ1 - μ2 = 0
# 2. Kemudian dipilih hipotesis alternatif H1 : μ1 - μ2 ≠ 0
# 3. Selanjutnya ditentukan tingkat signifikan α = 0.05
# 4. Akan digunakan uji statistik tes mean menggunakan Z, dan daerah kritis : z < -1.96 atau z > 1.96 diketahui dari P(Z < z) = 1 - (0.05/2) = 0.975
# 5. Akan dihitung nilai uji statistik dan p-valuenya

# %%
z = twoSampleMeanTestZ(df["Bulatan"].head(20), df["Bulatan"].tail(20), 0, df["Bulatan"])
print("Nilai uji =", z)
pValue = 2 * min(stats.norm.cdf(z), 1-stats.norm.cdf(z))
print("P-value =", pValue)

# Langkah 6. Ambil keputusan
if z < -1.96 or z > 1.96:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")

sns.boxplot(data=[df["Bulatan"].head(20), df["Bulatan"].tail(20)], orient="x", width=0.15).set_title("Boxplot Bulatan1 dan Bulatan2")
# Out:
# Nilai uji = -1.5266007543071642
# P-value = 0.12686031935430378
# H0 diterima karena nilai uji terletak di luar daerah kritis
# Text(0.5, 1.0, 'Boxplot Bulatan1 dan Bulatan2')

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimpulan yang dapat ditarik adalah rata-rata 20 baris pertama tidak sama dengan rata-rata 20 baris terakhir.

# %% [markdown]
# ## 5d. Proporsi nilai bagian awal Ransum yang lebih dari 2, adalah lebih besar daripada, proporsi nilai yang sama di bagian akhir Ransum?
# Misal p1 adalah proporsi bagian awal Ransum yang lebih dari 2 dan p2 adalah proporsi bagian akhir Ransum yang lebih dari 2. Langkah testing:
# 1. Ditentukan hipotesis nol H0 : p1 - p2 = 0
# 2. Kemudian dipilih hipotesis alternatif H1 : p1 - p2 > 0
# 3. Selanjutnya ditentukan tingkat signifikan α = 0.05
# 4. Akan digunakan uji statistik tes proporsi dua sampel menggunakan Z, dan daerah kritis : z > 1.645 diketahui dari P(Z < z) = 0.95
# 5. Akan dihitung nilai uji statistik dan p-valuenya

# %%
# Komputasi
p1 = len(df.head(250)[df.head(250)["Ransum"] > 2]) / 250
p2 = len(df.tail(250)[df.tail(250)["Ransum"] > 2]) / 250
pHat = (len(df.head(250)[df.head(250)["Ransum"] > 2]) + len(df.tail(250)[df.tail(250)["Ransum"] > 2])) / 500

z = (p1 - p2) / (math.sqrt(pHat * (1 - pHat) * (1/250 + 1/250)))
print("Nilai uji =", z)
pValue = 1 - stats.norm.cdf(z)
print("P-value =", pValue)

# Langkah 6. Ambil keputusan
if z > 1.645:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")

sns.boxplot(data=[df["Ransum"].head(250), df["Ransum"].tail(250)], orient="x", width=0.15).set_title("Boxplot Ransum1 dan Ransum2")
# Out:
# Nilai uji = 13.397486455610238
# P-value = 0.0
# H0 ditolak karena nilai uji terletak di daerah kritis
# Text(0.5, 1.0, 'Boxplot Ransum1 dan Ransum2')

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol ditolak, maka kesimpulan yang dapat ditarik adalah proporsi nilai bagian awal Ransum yang lebih dari 2 lebih besar daripada proporsi nilai yang sama di bagian akhir Ransum.

# %% [markdown]
# ## 5e. Bagian awal kolom Diameter memiliki variansi yang sama dengan bagian akhirnya?
# Misal σ12 adalah variansi bagian awal Diameter dan σ22 adalahvariansi bagian akhir Diameter.
# Langkah testing:
# 1. Ditentukan hipotesis nol H0 : σ12 = σ22
# 2. Kemudian dipilih hipotesis alternatif H1 : σ12 ≠ σ22
# 3. Selanjutnya ditentukan tingkat signifikan α = 0.05
# 4. Akan digunakan uji statistik tes variansi dua sampel menggunakan distribusi f. Hitung daerah kritis:

# %%
# Derahjat kebebasan = 249 dan 249
f1 = stats.f.ppf(0.025, 249, 249) # f1-α/2(v1,v2)
f2 = stats.f.ppf(0.975, 249, 249) # fα/2(v1,v2)
print("Daerah kritis = f <", f1, "atau f >", f2)
# Out:
# Daerah kritis = f < 0.7795916576054985 atau f > 1.2827228078241388

# %% [markdown]
# 5. Akan dihitung nilai uji statistik dan p-valuenya

# %%
# Komputasi
var1 = df.head(250)["Diameter"].var()
var2 = df.tail(250)["Diameter"].var()
F = var1 / var2
print("Nilai uji =", F)
pValue = 2 * min(stats.f.cdf(F, 249, 249), 1-stats.f.cdf(F, 249, 249))
print("P-value =", pValue)

# Langkah 6. Ambil keputusan
if F < f1 or F > f2:
    print("H0 ditolak karena nilai uji terletak di daerah kritis")
else:
    print("H0 diterima karena nilai uji terletak di luar daerah kritis")

sns.boxplot(data=[df["Diameter"].head(250), df["Diameter"].tail(250)], orient="x", width=0.15).set_title("Boxplot Diameter1 dan Diameter2")
# Out:
# Nilai uji = 1.083878022042188
# P-value = 0.5255791840378787
# H0 diterima karena nilai uji terletak di luar daerah kritis
# Text(0.5, 1.0, 'Boxplot Diameter1 dan Diameter2')

# %% [markdown]
# ### Kesimpulan
# Dikarenakan Hipotesis nol diterima, maka kesimpulan yang dapat ditarik adalah bagian awal kolom Diameter memiliki variansi yang sama dengan bagian akhirnya.

# %% [markdown]
# # 6. Test korelasi: tentukan apakah setiap kolom non-target berkorelasi dengan kolom target, dengan menggambarkan juga scatter plot nya. Gunakan correlation test.

# %% [markdown]
# Correlation test dilakukan menggunakan tes hipotesis dengan pearson's correlation test dengan
# - H0: p=0 (Kolom non-target dan kolom target tidak berkorelasi)
# - H1: p≠0 (Kolom non-target dan kolom target berkorelasi)
#
# Tes hipotesis ini menggunakan nilai alpha = 0.05
#
# Setelah didapatkan kesimpulan, scatter plot kedua kolom digambar

# %% [markdown]
# ## Korelasi Kolom Daerah dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["Daerah"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="Daerah", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.6027466517416654
# P-value = 8.925696449481286e-51
# <AxesSubplot:xlabel='Daerah', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom Daerah dan kolom Kelas berkorelasi. Korelasi antara kolom Daerah dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.6, yang berarti semakin besar nilai Daerah, nilai Kelas akan semakin kecil.

# %% [markdown]
# ## Korelasi Kolom SumbuUtama dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["SumbuUtama"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="SumbuUtama", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.7130906104204586
# P-value = 7.742407802553141e-79
# <AxesSubplot:xlabel='SumbuUtama', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom SumbuUtama dan kolom Kelas berkorelasi. Korelasi antara kolom SumbuUtama dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.71, yang berarti semakin besar nilai SumbuUtama, nilai Kelas akan semakin kecil.

# %% [markdown]
# ## Korelasi Kolom SumbuKecil dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["SumbuKecil"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="SumbuKecil", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.15297517335535019
# P-value = 0.0005985078116773203
# <AxesSubplot:xlabel='SumbuKecil', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom SumbuKecil dan kolom Kelas berkorelasi. Korelasi antara kolom SumbuKecil dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.15, yang berarti semakin besar nilai SumbuKecil, nilai Kelas akan semakin kecil.

# %% [markdown]
# ## Korelasi Kolom Keunikan dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["Keunikan"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="Keunikan", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.7304563686511918
# P-value = 1.649679087555956e-84
# <AxesSubplot:xlabel='Keunikan', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom Keunikan dan kolom Kelas berkorelasi. Korelasi antara kolom Keunikan dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.73, yang berarti semakin besar nilai Keunikan, nilai Kelas akan semakin kecil.

# %% [markdown]
# ## Korelasi Kolom AreaBulatan dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["AreaBulatan"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="AreaBulatan", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.6073125434153747
# P-value = 1.0113804362951908e-51
# <AxesSubplot:xlabel='AreaBulatan', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom AreaBulatan dan kolom Kelas berkorelasi. Korelasi antara kolom AreaBulatan dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.6, yang berarti semakin besar nilai AreaBulatan, nilai Kelas akan semakin kecil.

# %% [markdown]
# ## Korelasi Kolom Diameter dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["Diameter"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="Diameter", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.6025356896618808
# P-value = 9.862113990176893e-51
# <AxesSubplot:xlabel='Diameter', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom Diameter dan kolom Kelas berkorelasi. Korelasi antara kolom Diameter dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.6, yang berarti semakin besar nilai Diameter, nilai Kelas akan semakin kecil.

# %% [markdown]
# ## Korelasi Kolom KadarAir dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["KadarAir"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="KadarAir", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = 0.13434422605727633
# P-value = 0.002611048361291555
# <AxesSubplot:xlabel='KadarAir', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom KadarAir dan kolom Kelas berkorelasi. Korelasi antara kolom KadarAir dan kolom Kelas merupakan korelasi positif karena nilai koefisien korelasi 0.134, yang berarti semakin besar nilai KadarAir, nilai Kelas akan semakin besar pula.

# %% [markdown]
# ## Korelasi Kolom Keliling dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["Keliling"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="Keliling", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.634860745475685
# P-value = 9.078940431325306e-58
# <AxesSubplot:xlabel='Keliling', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom Keliling dan kolom Kelas berkorelasi. Korelasi antara kolom Keliling dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.634, yang berarti semakin besar nilai Keliling, nilai Kelas akan semakin kecil.

# %% [markdown]
# ## Korelasi Kolom Bulatan dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["Bulatan"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="Bulatan", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = 0.5450045317240073
# P-value = 5.0343757155661275e-40
# <AxesSubplot:xlabel='Bulatan', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom Bulatan dan kolom Kelas berkorelasi. Korelasi antara kolom Bulatan dan kolom Kelas merupakan korelasi positif karena nilai koefisien korelasi 0.55, yang berarti semakin besar nilai Bulatan, nilai Kelas akan semakin besar pula.

# %% [markdown]
# ## Korelasi Kolom Ransum dengan Kolom Kelas

# %%
cor, p = stats.pearsonr(df["Ransum"], df["Kelas"])
if p < alpha:
    print("H0 ditolak, kedua kolom berkorelasi")
else:
    print("H0 diterima, kedua kolom tidak berkorelasi")
    
print("Koefisien korelasi =", cor)
print("P-value =", p)

# Gambar scatter plot
sns.scatterplot(data=df, x="Ransum", y="Kelas")
# Out:
# H0 ditolak, kedua kolom berkorelasi
# Koefisien korelasi = -0.8399038681287483
# P-value = 2.8400940868088133e-134
# <AxesSubplot:xlabel='Ransum', ylabel='Kelas'>

# %% [markdown]
# ### Kesimpulan
# Kolom Ransum dan kolom Kelas berkorelasi. Korelasi antara kolom Ransum dan kolom Kelas merupakan korelasi negatif karena nilai koefisien korelasi -0.8399, yang berarti semakin besar nilai Ransum, nilai Kelas akan semakin kecil.
